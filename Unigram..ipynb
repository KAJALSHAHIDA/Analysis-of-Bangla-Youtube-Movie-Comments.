# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 


df=pd.read_excel(r"D:\Merge file.xlsx")

# %%
df
# Out:
#                                                   Comment Reaction       Tag  \
# 0                          শেখ হাসিনা কবে এই সিনেমা দেখবে        0  Negative
# 1                                   শেষ  ছবি  সালমান  শাহ        0  Positive
# 2                                  শেষ  টা দারুণ ছিল ️️️️        0  Positive
# 3              শেষ  পর্যন্ত কান্না আর ধরে রাখতে পারি নাই।        0  Positive
# 4       শেষ ৩০ মিনিট শুধুই কেঁদেছি। দুনিয়ায় যার টাকা ন...        0  Positive
# ...                                                   ...      ...       ...
# 122182     ছুট বেলা দেখেছিলাম আর আজ দেখলাম,, অসাধারণ মুভি        0       NaN
# 122183  যেমন কাহিনি তেমন অসাধারণ অভিনয়  প্রিয় নায়ক সাল...        0       NaN
# 122184                                               নাইস        4       NaN
# 122185                আহ বাংলা মুভি।  কিসের এখনকার বলিউড।        0       NaN
# 122186                                               রাইট        0       NaN
#
#        Unnamed: 3
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 122182        NaN
# 122183        NaN
# 122184        NaN
# 122185        NaN
# 122186        NaN
#
# [122187 rows x 4 columns]

# %%
import nltk
from nltk import FreqDist
from nltk.tokenize import word_tokenize
import pandas as pd
nltk.download('punkt')

df=pd.read_excel(r"D:\Merge file.xlsx")

def is_valid_bengali_word(word):
    bengali_range = (0x0980, 0x09FF)
    return all(ord(char) >= bengali_range[0] and ord(char) <= bengali_range[1] for char in word)

def preprocess_text(text):
    words = word_tokenize(text)
    bengali_words = [word for word in words if is_valid_bengali_word(word)]
    return bengali_words

text_column = df['Comment']
text_column = text_column.apply(lambda x: str(x))

bengali_unigrams = []

for comment in text_column:
    bengali_words = preprocess_text(comment)
    bengali_unigrams.extend(bengali_words)

fdist = FreqDist(bengali_unigrams)

output_data = {'Unigram': fdist.keys(), 'Frequency': fdist.values()}
output_df = pd.DataFrame(output_data)
output_df = output_df.sort_values(by='Frequency', ascending=False)

output_excel_path = 'Unigram_output.xlsx'
output_df.to_excel(output_excel_path, index=False)
print("Frequent unigram output saved to", output_excel_path)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Frequent unigram output saved to Unigram_output.xlsx
